# %%
Made by : ABBAOUI Achraf

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib notebook


Months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
#Climate data for Tétouan 1961-1990 normals
data_tet=pd.read_html('https://en.wikipedia.org/wiki/T%C3%A9touan')[1]
data_tet.drop([0,4,6,7,9,10,11],axis=0,inplace=True)
data_tet.replace(to_replace='[()](\d*\.\d*|°F)[)]',value='',inplace=True,regex=True)
data_tet.columns=['Variables','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']
data_tet.reset_index(inplace=True)
data_tet.drop('index',axis=1,inplace=True)
data_tet[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']] = data_tet[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']].apply(pd.to_numeric)

#Climate data for Rabat (Rabat–Salé Airport) 1961–1990
data_rs=pd.read_html("https://en.wikipedia.org/wiki/Rabat")[4]
data_rs.drop([0,9,6,4,7,10],axis=0,inplace=True)
data_rs.replace(to_replace='[()](\d*\.\d*|°F)[)]',value='',inplace=True,regex=True)
data_rs.columns=['Variables','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']
data_rs.reset_index(inplace=True)
data_rs.drop('index',axis=1,inplace=True)
data_rs[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']] = data_rs[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']].apply(pd.to_numeric)

#Climate data for Laayoune 1961–1990
data_la=pd.read_html("https://en.wikipedia.org/wiki/Laayoune")[1]
data_la.columns=['Variables','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']
data_la.drop(5,axis=0,inplace=True)
data_la.replace(to_replace='[()](\d*\.\d*|°F)[)]',value='',inplace=True,regex=True)
data_la[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']] = data_la[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Over a Year']].apply(pd.to_numeric)

#Plotting
daily_la=data_la.iloc[1][1:-1]
daily_tet=data_tet.iloc[1][1:-1]
daily_rs=data_rs.iloc[1][1:-1]
fig=plt.figure(figsize=(8,4))
plt.plot(daily_la.index,daily_la,label='Laayoune')
plt.plot(daily_tet.index,daily_tet,label='Tetouan')
plt.plot(daily_rs.index,daily_rs,label='Rabat-Sale')
plt.tick_params(left=False, top=False, bottom=False)
plt.legend()
plt.title('Average climate data for period 1961-1990 in different regions of Morocco')
plt.ylabel('Daily mean °C')
plt.grid(True,alpha=0.25)
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
